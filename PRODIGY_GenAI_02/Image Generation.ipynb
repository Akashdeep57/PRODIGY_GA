# %%
# !pip install torch torchvision transformers diffusers
# Out:
# Requirement already satisfied: torch in c:\users\akash\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: torchvision in c:\users\akash\anaconda3\lib\site-packages (0.18.1)
# Requirement already satisfied: transformers in c:\users\akash\anaconda3\lib\site-packages (4.25.1)
# Requirement already satisfied: diffusers in c:\users\akash\anaconda3\lib\site-packages (0.29.2)
# Requirement already satisfied: filelock in c:\users\akash\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\akash\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\akash\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\akash\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\akash\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\akash\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\akash\anaconda3\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: numpy in c:\users\akash\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\akash\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (0.24.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\akash\anaconda3\lib\site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\akash\anaconda3\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: importlib-metadata in c:\users\akash\anaconda3\lib\site-packages (from diffusers) (7.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\akash\anaconda3\lib\site-packages (from diffusers) (0.4.3)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\akash\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\akash\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.13.0)
# Requirement already satisfied: colorama in c:\users\akash\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\akash\anaconda3\lib\site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akash\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akash\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akash\anaconda3\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash\anaconda3\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\akash\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import matplotlib.pyplot as plt

def generate_image(prompt):
    # Load pre-trained model
    pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float32)
    
    # Move model to CPU
    pipe.to("cpu")
    
    # Generate image
    image = pipe(prompt).images[0]
    return image

def display_image(image):
    plt.imshow(image)
    plt.axis('off')  # Hide axes
    plt.show()

# %%
# Define a text prompt
prompt = "Sun set view at beach"

# Generate image
image = generate_image(prompt)

# Display the image
display_image(image)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
